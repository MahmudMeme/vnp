# %% [markdown]
# # Decision Trees and Gradient Boosting

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Setting up the Environment

# %% [markdown]
# For this laboratory exercise, you will need to install the Anaconda package & environment manager. We will install a minimal distribution, [Miniconda](https://docs.conda.io/projects/miniconda/en/latest/). Choose the adequate distribution for your operating system, download and install it.

# %% [markdown]
# Or use the following commands:
#
# ### Windows
# ```shell
# curl https://repo.anaconda.com/miniconda/Miniconda3-latest-Windows-x86_64.exe -o miniconda.exe
# start /wait "" miniconda.exe /S
# del miniconda.exe
# ```
#
# ### Linux
# ```shell
# mkdir -p ~/miniconda3
# wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh -O ~/miniconda3/miniconda.sh
# bash ~/miniconda3/miniconda.sh -b -u -p ~/miniconda3
# rm -rf ~/miniconda3/miniconda.sh
# ```
#
# ### macOS
#
# ```shell
# mkdir -p ~/miniconda3
# curl https://repo.anaconda.com/miniconda/Miniconda3-latest-MacOSX-arm64.sh -o ~/miniconda3/miniconda.sh
# bash ~/miniconda3/miniconda.sh -b -u -p ~/miniconda3
# rm -rf ~/miniconda3/miniconda.sh
# ```
#
# For both Linux and macOS after installing, initialize your newly-installed Miniconda. The following commands initialize for bash and zsh shells:
#
# ```shell
# ~/miniconda3/bin/conda init bash
# ~/miniconda3/bin/conda init zsh
# ```

# %% [markdown]
# Once you have installed miniconda, run the following commands to create an environment:
# ```bash
# conda create --name myenv
# ```
#
# 'myenv' is the name of the environment, you can change the name however you want.
#
# When conda asks you to proceed, type y

# %% [markdown]
# After successfully creating the environment, activate it with the following command:
# ```bash
# conda activate myenv
# ```

# %% [markdown]
# For more detailed information you can read the [documentation](https://conda.io/projects/conda/en/latest/user-guide/tasks/manage-environments.html#creating-an-environment-with-commands).

# %% [markdown]
# Now, once the environment is activated, proceed to install the required libraries.
#
# ```bash
# pip install numpy pandas scikit-learn xgboost matplotlib seaborn gdown
# ```

# %% [markdown]
# In the next step, we need to add the environment to jupyter. Use the following commands to install ipykernel and add the environment to ipykernel.
#
# ```bash
# pip install ipykernel
# ```
# ```bash
# python -m ipykernel install --name=myenv
# ```

# %% [markdown]
# Next, start Jupyter Notebook, download this starter notebook and open it. On the dropdown menu in the Kernel tab choose the name of the environment you created, like in the picture below.

# %% [markdown]
# ![jupyter](https://drive.google.com/uc?export=view&id=1N-27jjlIgpTILi-_6lny7ng8sE52SAZx)

# %% [markdown]
# ## Download and Read the Dataset

# %% [markdown]
# run the code below for downloading the dataset

# %%
# !gdown 1boIax8d9Sat6OJzkiIjjpqmtSZKuRYrx
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1boIax8d9Sat6OJzkiIjjpqmtSZKuRYrx
# To: /content/ElectricCarData.csv
# 100% 8.20k/8.20k [00:00<00:00, 22.9MB/s]

# %% [markdown]
# ### Import the required libraries

# %%
import pandas as pd

# %% [markdown]
# ### Read the dataset

# %% [markdown]
# CONTEXT:
# This is a dataset of electric vehicles.
#
# It contains the following columns:
#
#
# *   Brand
# *   Model
# *   AccelSec - Acceleration as 0-100 km/h
# *   TopSpeed_KmH - The top speed in km/h
# *   Range_Km - Range in km
# *   Efficiency_WhKm - Efficiency Wh/km
# *   FastCharge_KmH - Charge km/h
# *   RapidCharge - Yes / No
# *   PowerTrain - Front, rear, or all wheel drive
# *   PlugType
# *   BodyStyle - Basic size or style
# *   Segment - Market segment
# *   Seats - Number of seats
# *   PriceEuro - Price in Germany before tax incentives

# %% [markdown]
# TASK:
# Predict the target 'PriceEuro' and compare the performance of the DecisionTreeRegressor and the XGBRegressor models.

# %%
data = pd.read_csv('/content/ElectricCarData.csv')

# %%
data
# Out:
#      Brand  Model  AccelSec  TopSpeed_KmH  Range_Km  Efficiency_WhKm  \
# 0       30     46       4.6           233       450              161
# 1       31     33      10.0           160       270              167
# 2       23      0       4.7           210       400              181
# 3        2    101       6.8           180       360              206
# 4        9     78       9.5           145       170              168
# ..     ...    ...       ...           ...       ...              ...
# 98      20      6       7.5           160       330              191
# 99       1     94       4.5           210       335              258
# 100     20      8       5.9           200       325              194
# 101     20     10       5.1           200       375              232
# 102      3     42       7.5           190       400              238
#
#     FastCharge_KmH  RapidCharge  PowerTrain  PlugType  BodyStyle  Segment  \
# 0              940            1           0         2          7        3
# 1              250            1           2         2          1        2
# 2              620            1           0         2          2        3
# 3              560            1           2         2          6        3
# 4              190            1           2         2          1        1
# ..             ...          ...         ...       ...        ...      ...
# 98             440            1           1         2          1        2
# 99             540            1           0         2          6        4
# 100            440            1           0         2          1        2
# 101            450            1           0         2          1        2
# 102            480            1           0         2          6        4
#
#      Seats  PriceEuro
# 0        5      55480
# 1        5      30000
# 2        5      56440
# 3        5      68040
# 4        4      32997
# ..     ...        ...
# 98       5      45000
# 99       5      96050
# 100      5      50000
# 101      5      65000
# 102      5      62000
#
# [103 rows x 14 columns]

# %%
data.head()
# Out:
#          Brand                          Model  AccelSec  TopSpeed_KmH  \
# 0       Tesla   Model 3 Long Range Dual Motor       4.6           233
# 1  Volkswagen                       ID.3 Pure      10.0           160
# 2    Polestar                               2       4.7           210
# 3         BMW                            iX3        6.8           180
# 4       Honda                              e        9.5           145
#
#    Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# 0       450              161            940         Yes        AWD
# 1       270              167            250         Yes        RWD
# 2       400              181            620         Yes        AWD
# 3       360              206            560         Yes        RWD
# 4       170              168            190         Yes        RWD
#
#      PlugType  BodyStyle Segment  Seats  PriceEuro
# 0  Type 2 CCS      Sedan       D      5      55480
# 1  Type 2 CCS  Hatchback       C      5      30000
# 2  Type 2 CCS   Liftback       D      5      56440
# 3  Type 2 CCS        SUV       D      5      68040
# 4  Type 2 CCS  Hatchback       B      4      32997

# %% [markdown]
# ### Encode string variables

# %%
data.isnull().sum()
# Out:
# Brand              0
# Model              0
# AccelSec           0
# TopSpeed_KmH       0
# Range_Km           0
# Efficiency_WhKm    0
# FastCharge_KmH     0
# RapidCharge        0
# PowerTrain         0
# PlugType           0
# BodyStyle          0
# Segment            0
# Seats              0
# PriceEuro          0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
data.columns
# Out:
# Index(['Brand', 'Model', 'AccelSec', 'TopSpeed_KmH', 'Range_Km',
#        'Efficiency_WhKm', 'FastCharge_KmH', 'RapidCharge', 'PowerTrain',
#        'PlugType', 'BodyStyle', 'Segment', 'Seats', 'PriceEuro'],
#       dtype='object')

# %%
data.head(1)
# Out:
#     Brand                          Model  AccelSec  TopSpeed_KmH  Range_Km  \
# 0  Tesla   Model 3 Long Range Dual Motor       4.6           233       450
#
#    Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain    PlugType  \
# 0              161            940         Yes        AWD  Type 2 CCS
#
#   BodyStyle Segment  Seats  PriceEuro
# 0     Sedan       D      5      55480

# %%
col=['Brand', 'Model',  'PowerTrain','PlugType', 'BodyStyle', 'Segment', 'TopSpeed_KmH', 'Range_Km',
       'Efficiency_WhKm', 'FastCharge_KmH']
for c in col:
  data[c]=le.fit_transform(data[c])
#data['Brand', 'Model',  'PowerTrain','PlugType', 'BodyStyle', 'Segment',  'PriceEuro']=le.fit_transform(data['Brand', 'Model',  'PowerTrain','PlugType', 'BodyStyle', 'Segment',  'PriceEuro'])

# %%
data.head()
# Out:
#    Brand  Model  AccelSec  TopSpeed_KmH  Range_Km  Efficiency_WhKm  \
# 0     30     46       4.6            18        42                5
# 1     31     33      10.0             9        15                9
# 2     23      0       4.7            15        35               21
# 3      2    101       6.8            12        28               32
# 4      9     78       9.5             5         4               10
#
#    FastCharge_KmH  RapidCharge  PowerTrain  PlugType  BodyStyle  Segment  \
# 0              50            1           0         2          7        3
# 1               7            1           2         2          1        2
# 2              36            1           0         2          2        3
# 3              32            1           2         2          6        3
# 4               2            1           2         2          1        1
#
#    Seats  PriceEuro
# 0      5      55480
# 1      5      30000
# 2      5      56440
# 3      5      68040
# 4      4      32997

# %%
data['RapidCharge']=le.fit_transform(data['RapidCharge'])

# %%
data.head(5)
# Out:
#    Brand  Model  AccelSec  TopSpeed_KmH  Range_Km  Efficiency_WhKm  \
# 0     30     46       4.6            18        42                5
# 1     31     33      10.0             9        15                9
# 2     23      0       4.7            15        35               21
# 3      2    101       6.8            12        28               32
# 4      9     78       9.5             5         4               10
#
#    FastCharge_KmH  RapidCharge  PowerTrain  PlugType  BodyStyle  Segment  \
# 0              50            1           0         2          7        3
# 1               7            1           2         2          1        2
# 2              36            1           0         2          2        3
# 3              32            1           2         2          6        3
# 4               2            1           2         2          1        1
#
#    Seats  PriceEuro
# 0      5      55480
# 1      5      30000
# 2      5      56440
# 3      5      68040
# 4      4      32997

# %%
data.columns
# Out:
# Index(['Brand', 'Model', 'AccelSec', 'TopSpeed_KmH', 'Range_Km',
#        'Efficiency_WhKm', 'FastCharge_KmH', 'RapidCharge', 'PowerTrain',
#        'PlugType', 'BodyStyle', 'Segment', 'Seats', 'PriceEuro'],
#       dtype='object')

# %% [markdown]
# ## Split the dataset for training and testing in ratio 80:20

# %%
from sklearn.model_selection import train_test_split
X,Y=data.drop(columns=['PriceEuro']),data['PriceEuro']

X_train, X_test, Y_train, Y_test = train_test_split( X,Y, test_size=0.2)

# %% [markdown]
# ## Initialize the DecisionTreeRegressor model, and use the fit function for training the model.
#
# Add values for the parameters max_depth, min_samples_split, and max_features.

# %% [markdown]
# Fit the model using the fit function

# %%
from sklearn.tree import DecisionTreeRegressor

classifier = DecisionTreeRegressor(max_depth=13)
classifier = classifier.fit(X_train,Y_train)

# %% [markdown]
# ## Predict the outcomes for X test

# %%
y_pred = classifier.predict(X_test)

# %% [markdown]
# ## Assess the model performance, by using sklearn metrics for regression

# %%
from sklearn import metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score


print("Accuracy:",classifier.score(X_test, Y_test))
# Out:
# Accuracy: 0.82289800436795

# %%
print("Mean Absolute Error : " + str(mean_absolute_error(y_pred, Y_test)))
print("Mean Squared Error : " + str(mean_squared_error(y_pred, Y_test)))
# Out:
# Mean Absolute Error : 16508.67540922619
# Mean Squared Error : 512933924.1128751

# %%
print(r2_score(Y_test,y_pred))
# Out:
# 0.5627779680487306

# %% [markdown]
# ## Initialize the XGBRegressor model, and use the fit function

# %% [markdown]
# Add values for the parameters: n_estimators, max_depth, learning_rate, and set the objective to "reg:squarederror"

# %% [markdown]
# Fit the model using the fit function

# %%
from xgboost import XGBRegressor

model = XGBRegressor(objective ='reg:linear',colsample_bytree=0.3,learning_rate=0.1,max_depth=10,alpha=2,n_estimators=10)
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [17:54:02] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# XGBRegressor(alpha=2, base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.3, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=10, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=10, n_jobs=None,
#              num_parallel_tree=None, ...)

# %% [markdown]
# ## Predict the outcomes for X test

# %%
y_pred2 = model.predict(X_test)

# %% [markdown]
# ## Assess the model performance, by using sklearn metrics for regression

# %%
print(r2_score(Y_test,y_pred2))
# Out:
# 0.569616195460743

# %% [markdown]
# ## Compare the performances of both model for at least three regression metircs

# %%
bestr=0
bestdepth=0
for i in range (5,20,5):
  model = XGBRegressor(objective ='reg:linear',colsample_bytree=0.3,learning_rate=0.1,max_depth=i,alpha=2,n_estimators=10)
  model.fit(X_train, Y_train)
  y_pred3 = model.predict(X_test)
  r=r2_score(Y_test,y_pred3)
  if r>bestr:
    bestr=r
    bestdepth=i

print(bestr)
print(bestdepth)
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [18:01:51] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# 0.569616195460743
# 10
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [18:01:52] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [18:01:52] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)

# %%
bestn=0
bestestimators=0
for i in range (10,30,5):
  model = XGBRegressor(objective ='reg:linear',colsample_bytree=0.3,learning_rate=0.1,max_depth=bestdepth,alpha=2,n_estimators=i)
  model.fit(X_train, Y_train)
  y_pred3 = model.predict(X_test)
  r=r2_score(Y_test,y_pred3)
  if r>bestn:
    bestn=r
    bestestimators=i

print(bestn)
print(bestestimators)
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [18:06:15] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [18:06:15] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [18:06:15] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [18:06:15] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# 0.7576066738443046
# 25

# %%
bestapha=0
bestealphas=0
all=[2,1,0.1,0.01,0.001]
for i in all:
  model = XGBRegressor(objective ='reg:linear',colsample_bytree=0.3,learning_rate=0.1,max_depth=bestdepth,alpha=i,n_estimators=bestestimators)
  model.fit(X_train, Y_train)
  y_pred3 = model.predict(X_test)
  r=r2_score(Y_test,y_pred3)
  if r>bestapha:
    bestapha=r
    bestealphas=i

print(bestapha)
print(bestealphas)
# Out:
# 0.7576142682363802
# 0.001
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [18:06:40] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [18:06:40] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [18:06:40] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [18:06:40] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [18:06:40] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
